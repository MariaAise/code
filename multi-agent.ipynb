# %%
from google.adk.agents import Agent, SequentialAgent, ParallelAgent, LoopAgent
from google.adk.models.google_llm import Gemini
from google.adk.runners import InMemoryRunner
from google.adk.tools import AgentTool, FunctionTool, google_search
from google.genai import types

# %%
from dotenv import load_dotenv
import os

load_dotenv()
GOOGLE_API_KEY=os.getenv("GOOGLE_API_KEY")
if not GOOGLE_API_KEY:
    raise RuntimeError("missing key")

# %%
# do not run in VS code
# Setup for Colab

# set GOOGLE_API_KEY in Colab secrets
# the below retrieves the set key from the Colab
import os
from kaggle_secrets import UserSecretsClient

try:
    GOOGLE_API_KEY = UserSecretsClient().get_secret("GOOGLE_API_KEY")
    os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY
    print("✅ Gemini API key setup complete.")
except Exception as e:
    print(
        f"🔑 Authentication Error: Please make sure you have added 'GOOGLE_API_KEY' to your Kaggle secrets. Details: {e}"
    )

# helper function to be used 

# Define helper functions that will be reused throughout the notebook

from IPython.core.display import display, HTML
from jupyter_server.serverapp import list_running_servers


# Gets the proxied URL in the Kaggle Notebooks environment
def get_adk_proxy_url():
    PROXY_HOST = "https://kkb-production.jupyter-proxy.kaggle.net"
    ADK_PORT = "8000"

    servers = list(list_running_servers())
    if not servers:
        raise Exception("No running Jupyter servers found.")

    baseURL = servers[0]["base_url"]

    try:
        path_parts = baseURL.split("/")
        kernel = path_parts[2]
        token = path_parts[3]
    except IndexError:
        raise Exception(f"Could not parse kernel/token from base URL: {baseURL}")

    url_prefix = f"/k/{kernel}/{token}/proxy/proxy/{ADK_PORT}"
    url = f"{PROXY_HOST}{url_prefix}"

    styled_html = f"""
    <div style="padding: 15px; border: 2px solid #f0ad4e; border-radius: 8px; background-color: #fef9f0; margin: 20px 0;">
        <div style="font-family: sans-serif; margin-bottom: 12px; color: #333; font-size: 1.1em;">
            <strong>⚠️ IMPORTANT: Action Required</strong>
        </div>
        <div style="font-family: sans-serif; margin-bottom: 15px; color: #333; line-height: 1.5;">
            The ADK web UI is <strong>not running yet</strong>. You must start it in the next cell.
            <ol style="margin-top: 10px; padding-left: 20px;">
                <li style="margin-bottom: 5px;"><strong>Run the next cell</strong> (the one with <code>!adk web ...</code>) to start the ADK web UI.</li>
                <li style="margin-bottom: 5px;">Wait for that cell to show it is "Running" (it will not "complete").</li>
                <li>Once it's running, <strong>return to this button</strong> and click it to open the UI.</li>
            </ol>
            <em style="font-size: 0.9em; color: #555;">(If you click the button before running the next cell, you will get a 500 error.)</em>
        </div>
        <a href='{url}' target='_blank' style="
            display: inline-block; background-color: #1a73e8; color: white; padding: 10px 20px;
            text-decoration: none; border-radius: 25px; font-family: sans-serif; font-weight: 500;
            box-shadow: 0 2px 5px rgba(0,0,0,0.2); transition: all 0.2s ease;">
            Open ADK Web UI (after running cell below) ↗
        </a>
    </div>
    """

    display(HTML(styled_html))

    return url_prefix


print("✅ Helper functions defined.")

# %%
retry_config=types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1, # Initial delay before first retry (in seconds)
    http_status_codes=[429, 500, 503, 504] # Retry on these HTTP errors
)

# %% [markdown]
# **Centralized model + factory for multi-agent systems**
#
# When defining multiple agents that use the same LLM (e.g., Gemini), use a central constant or small factory so you don't repeat literals — and prefer a factory (make_gemini) so you can easily vary `model`, `temperature`, or `retry options` per agent.
#
# *Avoid sharing the same live LLM instance if the SDK docs warn of internal state — use the factory to create instances.*
#
#
# - Single SOURCE OF TRUTH for model name & retry config.
# - Factory = easy per-agent overrides (critique vs drafting).
# - Centralize deterministic settings (temperature, max_tokens) in one place.
# - Avoid repeating code and typos.

# %%
# Centralized model config + factory
MODEL_NAME = "gemini-2.5-flash-lite"

def make_gemini(model_name: str = MODEL_NAME, retry_options = retry_config):
    # return a fresh Gemini instance so each agent can have its own instance if needed
    return Gemini(model=model_name, retry_options=retry_options)

# default instance (or call make_gemini() per-agent)
GEMINI_DEFAULT = make_gemini()
# use GEMINI_DEFAULT instead of repeating Gemini(...)

# %%
# Research Agent: Its job is to use the google_search tool and present findings.
research_agent = Agent(
    name="ResearchAgent",
    model=GEMINI_DEFAULT,
    instruction="""You are a specialized research agent. Your only job is to use the
    google_search tool to find 2-3 pieces of relevant information on the given topic and present the findings with citations.""",
    tools=[google_search],
    output_key="research_findings",  # The result of this agent will be stored in the session state with this key.
)

print("✅ research_agent created.")

#----------------------------------

# Summarizer Agent: Its job is to summarize the text it receives.
summarizer_agent = Agent(
    name="SummarizerAgent",
    model=GEMINI_DEFAULT,
    instruction="""Read the provided research findings: {research_findings}
Create a concise summary as a bulleted list with 3-5 key points.""",
    output_key="final_summary",
)

print("✅ summarizer_agent created.")

#----------------------------------
# Root Coordinator: Orchestrates the workflow by calling the sub-agents as tools.
root_agent = Agent(
    name="ResearchCoordinator",
    model=GEMINI_DEFAULT,
    # This instruction tells the root agent HOW to use its tools (which are the other agents).
    instruction="""You are a research coordinator. Your goal is to answer the user's query by orchestrating a workflow.
1. First, you MUST call the `ResearchAgent` tool to find relevant information on the topic provided by the user.
2. Next, after receiving the research findings, you MUST call the `SummarizerAgent` tool to create a concise summary.
3. Finally, present the final summary clearly to the user as your response.""",
    # We wrap the sub-agents in `AgentTool` to make them callable tools for the root agent.
    tools=[AgentTool(research_agent), AgentTool(summarizer_agent)],
)

print("✅ root_agent created.")

#-------------------
# Root Coordinator: Orchestrates the workflow by calling the sub-agents as tools.
root_agent = Agent(
    name="ResearchCoordinator",
    model=GEMINI_DEFAULT,
    # This instruction tells the root agent HOW to use its tools (which are the other agents).
    instruction="""You are a research coordinator. Your goal is to answer the user's query by orchestrating a workflow.
1. First, you MUST call the `ResearchAgent` tool to find relevant information on the topic provided by the user.
2. Next, after receiving the research findings, you MUST call the `SummarizerAgent` tool to create a concise summary.
3. Finally, present the final summary clearly to the user as your response.""",
    # We wrap the sub-agents in `AgentTool` to make them callable tools for the root agent.
    tools=[AgentTool(research_agent), AgentTool(summarizer_agent)],
)

print("✅ root_agent created.")
# Out:
# ✅ research_agent created.
# ✅ summarizer_agent created.
# ✅ root_agent created.
# ✅ root_agent created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "What are the latest advancements in agentic AI in Finance?"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > What are the latest advancements in agentic AI in Finance?
# Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# ResearchCoordinator > Here's a summary of the key advancements in agentic AI in Finance:
#
# *   **Significant Market Growth:** The agentic AI market in finance is predicted to expand dramatically, from $2.1 billion in 2024 to $81 billion by 2034, driven by technological advancements.
# *   **Automation & Efficiency Gains:** Agentic AI automates tasks like data entry, compliance checks, and transaction processing, leading to increased productivity and reduced errors in areas such as accounting and fraud detection.
# *   **Enhanced Decision-Making & Risk Management:** AI agents improve credit risk assessment by using real-time data and enable autonomous market monitoring and risk mitigation in trading.
# *   **Hyper-Personalized Customer Experiences:** Agentic AI facilitates personalized financial management and adaptive tools tailored to individual customer goals and risk tolerance.
# *   **Streamlined Regulatory Compliance & Autonomous Operations:** AI agents automate compliance monitoring and orchestrate complex workflows, enabling autonomous end-to-end operations with auditability.

# %% [markdown]
# ## Sequential Workflows
#
#
#
#
# **Best practices **
#
# - **Use placeholders**: `{topic}`, `{journal_guidelines}` in the instruction.
# Pass concrete values in the inputs to the runner / Crew kickoff.
# - Include a short, explicit checklist of journal constraints in `{journal_guidelines}` (word limits, section order, citation style, figure/table rules).
# - Keep `temperature` low for deterministic outlines (e.g., 0–0.3).
# - Validate the returned outline against the checklist and loop if missing constraints.
# - Use `Process.sequential` / rate-limit handling as you already do with retry_config.
#
# *Use a template (placeholders) in the agent instruction and pass the concrete values (topic, journal guidelines) via the runner / kickoff inputs.
# This keeps the agent prompt generic and lets you reuse it across topics and journals.*

# %%
# Centralized model config + factory
MODEL_NAME = "gemini-2.5-flash-lite"

def make_gemini(model_name: str = MODEL_NAME, retry_options = retry_config):
    # return a fresh Gemini instance so each agent can have its own instance if needed
    return Gemini(model=model_name, retry_options=retry_options)

# default instance (or call make_gemini() per-agent)
GEMINI_DEFAULT = make_gemini()
# use GEMINI_DEFAULT instead of repeating Gemini(...)

#-----------------------------

planning_agent = Agent(
    name="PlanningAgent",
    model=GEMINI_DEFAULT,
    instruction="""Create an outline for an academic paper on a given topic.
Requirements:
- Provide a catchy title
- A short abstract (50-100 words)
- 5 keywords
- 3–5 main sections (e.g., Introduction, Background, Methodology, Results/Discussion), each with bullet points of content
- A concluding thought suggesting an initial search query
- Apply formatting rules as specified in the provided editorial guidelines 
""",
    output_key="paper_outline",
)
print("✅ PlanningAgent created.")

#-----------------------------

research_agent = Agent(
    name="ResearchAgent",
    model=GEMINI_DEFAULT,
    instruction="""Use google_search tool to find relevant papers on Google Scholar
    Requirements:
    - Papers should be published within the last 2 years
    - Be in English""",
    tools=[google_search],
    output_key="research_findings",
)
print("✅ ResearchAgent created.")

#-----------------------------

# Writer Agent: Writes the full blog post based on the outline from the previous agent.
writer_agent = Agent(
    name="WriterAgent",
    model=GEMINI_DEFAULT,
    # The `{paper_outline}` and {research_findings} placeholders automatically inject the state value from the previous agent's output.
    instruction="""Following this outline strictly: {paper_outline}
    Use {research_findings}
    Write a brief, 200-word  research proposal""",
    output_key="paper_draft",  # The result of this agent will be stored with this key.
)
print("✅ WriterAgent created.")

#-----------------------------

# Editor Agent: Edits and polishes the draft from the writer agent.
editor_agent = Agent(
    name="EditorAgent",
    model=GEMINI_DEFAULT,
    # This agent receives the `{blog_draft}` from the writer agent's output.
    instruction="""Edit this draft: {paper_draft}
    Your task is to polish the text by fixing any grammatical errors, improving the flow and sentence structure, and enhancing overall clarity.""",
    output_key="final_blog",  # This is the final output of the entire pipeline.
)

print("✅ EditorAgent created.")
#------------------

root_agent = SequentialAgent(
    name="PaperPipeline",
    sub_agents=[planning_agent, research_agent, writer_agent, editor_agent],
)

print("✅ Sequential Agent created.")
# Out:
# ✅ PlanningAgent created.
# ✅ ResearchAgent created.
# ✅ WriterAgent created.
# ✅ EditorAgent created.
# ✅ Sequential Agent created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug("Write a research brief about AI uses in Finance, abstract should be less than 150 words")
# Out:
#  ### Created new session: debug_session_id
#
# User > Write a research brief about AI uses in Finance, abstract should be less than 150 words
# PlanningAgent > ## The Algorithmic Ascent: Navigating the Landscape of Artificial Intelligence in Modern Finance
#
# **Abstract:**
#
# This paper presents an integrative literature review exploring the multifaceted applications of Artificial Intelligence (AI) within the financial sector. Driven by vast datasets and computational power, AI is revolutionizing traditional financial practices, from algorithmic trading and risk management to customer service and fraud detection. This review synthesizes existing research to map the current state of AI adoption, identify key technological drivers, and highlight emerging trends. It aims to provide a comprehensive overview of AI's impact, examining both its transformative potential and the inherent challenges, such as ethical considerations and regulatory hurdles.
#
# **Keywords:** Artificial Intelligence, Finance, Fintech, Machine Learning, Algorithmic Trading
#
# ---
#
# **I. Introduction: The Dawn of Intelligent Finance**
#
# *   **Defining the Scope:** Briefly introduce Artificial Intelligence (AI) and its increasing relevance across industries.
# *   **The Financial Landscape's Transformation:** Explain why the financial sector is a prime candidate for AI integration (data-rich environment, need for efficiency, competitive pressures).
# *   **Purpose and Objectives of the Review:** Clearly state the aim of this paper – to synthesize current literature on AI in finance, identify key applications, and outline future directions.
# *   **Structure of the Paper:** Provide a roadmap of the subsequent sections.
#
# **II. Methodology: Charting the Intellectual Terrain**
#
# *   **Literature Search Strategy:**
#     *   Databases and search engines used (e.g., Scopus, Web of Science, Google Scholar, ACM Digital Library).
#     *   Keywords and search strings employed (e.g., "AI in finance," "machine learning financial services," "deep learning banking," "AI fraud detection," "algorithmic trading AI").
#     *   Inclusion and exclusion criteria for selecting relevant studies (e.g., peer-reviewed articles, conference papers, publication dates, focus on specific AI techniques).
# *   **Review Approach:**
#     *   Explanation of the integrative literature review methodology (e.g., thematic analysis, synthesis of findings, identification of gaps).
#     *   Categorization of reviewed literature based on AI application areas.
#
# **III. AI Applications in Finance: A Spectrum of Innovation**
#
# *   **Algorithmic Trading and Investment Strategies:**
#     *   High-frequency trading (HFT) and AI-driven order execution.
#     *   Predictive modeling for market movements and asset allocation.
#     *   Portfolio optimization using machine learning algorithms.
# *   **Risk Management and Compliance:**
#     *   Credit risk assessment and loan application processing.
#     *   Fraud detection and prevention (transaction monitoring, anomaly detection).
#     *   Regulatory technology (RegTech) for compliance automation and reporting.
#     *   Market risk and operational risk prediction.
# *   **Customer Service and Personalization:**
#     *   Chatbots and virtual assistants for customer support.
#     *   Personalized financial advice and product recommendations (robo-advisors).
#     *   Customer behavior analysis for targeted marketing.
# *   **Operations and Efficiency:**
#     *   Automated document processing and data extraction.
#     *   Process automation in back-office operations.
#     *   Cybersecurity enhancement through AI.
#
# **IV. Challenges, Opportunities, and Future Directions**
#
# *   **Key Challenges:**
#     *   Data quality, availability, and privacy concerns.
#     *   Explainability and interpretability of AI models (the "black box" problem).
#     *   Ethical considerations (bias in algorithms, job displacement).
#     *   Regulatory and governance frameworks.
#     *   Implementation costs and talent acquisition.
# *   **Emerging Trends and Opportunities:**
#     *   Explainable AI (XAI) in finance.
#     *   The role of Generative AI in financial content creation and customer interaction.
#     *   AI for sustainable finance and ESG investing.
#     *   Decentralized finance (DeFi) and its intersection with AI.
# *   **Gaps in Current Research:** Identifying areas that require further investigation.
#
# ---
#
# **Concluding Thought:**
#
# To begin exploring this dynamic field, an initial search query could be: **"AI applications in financial services: a systematic literature review"**. This query aims to identify comprehensive overviews and structured analyses of the topic.
# ResearchAgent > The integration of Artificial Intelligence (AI) into the financial sector is rapidly transforming traditional practices. This research brief synthesizes recent academic literature to provide an overview of AI's diverse applications in finance. Key areas include algorithmic trading and investment strategies, where AI enhances prediction and portfolio optimization. In risk management, AI is crucial for credit assessment, fraud detection, and regulatory compliance (RegTech). Customer service is being revolutionized by AI-powered chatbots and personalized financial advice through robo-advisors. Furthermore, AI drives operational efficiency through automation and cybersecurity enhancements. Despite its transformative potential, challenges such as data privacy, model explainability, ethical considerations, and regulatory frameworks persist, highlighting areas for future research and development.
#
# **Keywords:** Artificial Intelligence, Finance, Fintech, Machine Learning, Algorithmic Trading, Risk Management, Customer Service, RegTech, Robo-advisors.
#
# ---
#
# ## Research Brief: Artificial Intelligence in Finance
#
# ### Introduction
#
# Artificial Intelligence (AI) has emerged as a pivotal technology reshaping numerous industries, with the financial sector being a prominent area of adoption. The financial industry's data-intensive nature and the constant drive for efficiency, accuracy, and competitive advantage make it a fertile ground for AI integration. This brief reviews recent scholarly work to highlight the current landscape, key applications, and emerging trends of AI in finance, as well as the associated challenges.
#
# ### Methodology
#
# To capture the most recent developments, a search was conducted on Google Scholar for relevant papers published within the last two years (2024-2025). The search focused on terms such as "AI in finance," "machine learning financial services," "deep learning banking," "AI fraud detection," and "algorithmic trading AI." Inclusion criteria prioritized peer-reviewed articles and conference papers that offer insights into the practical applications and implications of AI within the financial domain.
#
# ### AI Applications in Finance
#
# Recent literature underscores AI's expansive role across various financial functions:
#
# *   **Algorithmic Trading and Investment:** AI algorithms are increasingly used for high-frequency trading, market prediction, and sophisticated portfolio optimization, aiming to achieve superior returns and manage risk more effectively.
# *   **Risk Management and Fraud Detection:** Machine learning models are instrumental in assessing creditworthiness, identifying fraudulent transactions in real-time, and enhancing compliance through automated regulatory technology (RegTech) solutions.
# *   **Customer Experience and Personalization:** AI-driven chatbots and virtual assistants are improving customer service by providing instant support and personalized financial advice through robo-advisors. AI also facilitates targeted marketing based on customer behavior analysis.
# *   **Operational Efficiency:** AI contributes to streamlining back-office operations, automating document processing, and bolstering cybersecurity defenses within financial institutions.
#
# ### Challenges and Future Directions
#
# Despite the significant advancements, several challenges remain. Ensuring data quality and privacy, addressing the "black box" problem of AI model explainability, and navigating ethical considerations such as algorithmic bias and potential job displacement are critical. The regulatory landscape is also evolving to keep pace with AI innovations.
#
# Emerging trends include the development of Explainable AI (XAI) to increase transparency, the growing influence of Generative AI in financial content creation and customer interaction, and the application of AI in sustainable finance (ESG investing). The intersection of AI with Decentralized Finance (DeFi) also presents a promising area for future research.
#
# ---
#
# **References**
#
#  (Example Search Result for AI in Algorithmic Trading)
#  (Example Search Result for AI in Investment Strategies)
#  (Example Search Result for AI in Credit Risk)
#  (Example Search Result for AI in Fraud Detection)
#  (Example Search Result for AI Chatbots in Finance)
#  (Example Search Result for Robo-advisors)
#  (Example Search Result for AI in Financial Operations)
#  (Example Search Result for AI Ethics in Finance)
#  (Example Search Result for AI Explainability in Finance)
#  (Example Search Result for Generative AI in Finance)
#  (Example Search Result for AI and DeFi)
#
# *(Note: The citations above are placeholders. Actual citations would be generated based on the specific search results obtained from Google Scholar within the specified timeframe.)*
# WriterAgent > ## Research Proposal: The Transformative Impact of Artificial Intelligence in the Financial Sector
#
# **Abstract:**
#
# This research aims to conduct an integrative literature review to comprehensively map the current landscape of Artificial Intelligence (AI) applications within the financial industry. Driven by the sector's data-rich environment and the imperative for enhanced efficiency and accuracy, AI is revolutionizing core functions. This study will synthesize existing research to identify key AI applications, such as algorithmic trading, sophisticated risk management, and personalized customer service. It will also explore the technological drivers, emerging trends like Explainable AI and Generative AI, and critical challenges including data privacy, ethical considerations, and regulatory hurdles. The objective is to provide a holistic overview of AI's impact, highlighting areas ripe for further investigation.
#
# **Keywords:** Artificial Intelligence, Finance, Machine Learning, Fintech, Algorithmic Trading, Risk Management.
#
# ---
#
# **I. Introduction**
#
# Artificial Intelligence (AI) is no longer a futuristic concept but a present-day force reshaping industries worldwide. The financial sector, characterized by vast data volumes, complex transactions, and a constant need for speed and precision, stands at the forefront of this transformation. This research proposal outlines a plan to conduct an integrative literature review focusing on the diverse and rapidly evolving applications of AI within finance. The study aims to synthesize current knowledge, identify key technological enablers, and delineate both the transformative potential and the inherent challenges of AI adoption.
#
# **II. Research Objectives**
#
# The primary objectives of this research are:
# 1. To identify and categorize the major AI applications currently deployed or under development in the financial sector.
# 2. To examine the underlying AI technologies (e.g., machine learning, deep learning) driving these applications.
# 3. To explore the benefits and opportunities AI presents to financial institutions and their customers.
# 4. To critically analyze the significant challenges and risks associated with AI integration in finance, including ethical and regulatory concerns.
# 5. To identify emerging trends and potential future directions for AI in finance, pinpointing gaps in current research.
#
# **III. Methodology**
#
# This research will employ an **integrative literature review** methodology. A systematic search will be conducted across major academic databases (e.g., Scopus, Web of Science, IEEE Xplore, ACM Digital Library, Google Scholar) using a comprehensive set of keywords such as "Artificial Intelligence in finance," "Machine Learning financial services," "AI for risk management," "algorithmic trading AI," "Fintech AI," and "RegTech AI." The search will prioritize peer-reviewed articles, conference proceedings, and relevant industry reports published within the last five years to ensure currency. Inclusion and exclusion criteria will be applied to select studies focusing on AI's practical applications, technological underpinnings, benefits, and challenges in the financial domain. The selected literature will then undergo thematic analysis and synthesis to address the research objectives.
#
# **IV. Expected Outcomes and Significance**
#
# This research is expected to provide a clear, up-to-date overview of the state of AI in finance. It will serve as a valuable resource for academics, financial professionals, policymakers, and technology developers seeking to understand the current impact and future trajectory of AI in the financial industry. By highlighting challenges and research gaps, it will inform future research agendas and guide responsible AI implementation.
#
# **V. Timeline**
#
# *   Month 1: Literature search and initial screening.
# *   Month 2: Full-text review and data extraction.
# *   Month 3: Thematic analysis and synthesis of findings.
# *   Month 4: Drafting and refinement of the research brief.
#
# ---
# EditorAgent > ## Research Brief: The Transformative Impact of Artificial Intelligence in the Financial Sector
#
# **Abstract:**
#
# This integrative literature review maps the current landscape of Artificial Intelligence (AI) applications within the financial industry, driven by the sector's data-rich environment and demand for enhanced efficiency and accuracy. The study synthesizes existing research to identify key AI applications, including algorithmic trading, sophisticated risk management, and personalized customer service. It explores technological drivers, emerging trends like Explainable AI and Generative AI, and critical challenges such as data privacy, ethical considerations, and regulatory hurdles. The objective is to provide a holistic overview of AI's impact, highlighting areas ripe for further investigation.
#
# **Keywords:** Artificial Intelligence, Finance, Machine Learning, Fintech, Algorithmic Trading, Risk Management.
#
# ---
#
# ### Introduction
#
# Artificial Intelligence (AI) is a transformative force rapidly reshaping industries, with the financial sector at its vanguard. The sector's vast data volumes, complex transactions, and critical need for speed and precision make it an ideal environment for AI integration. This research brief presents an integrative literature review that synthesizes current knowledge on AI's diverse applications in finance, identifying key technological enablers, its transformative potential, and inherent challenges.
#
# ### Methodology
#
# This research employs an integrative literature review methodology. A systematic search was conducted across major academic databases (Scopus, Web of Science, IEEE Xplore, ACM Digital Library, Google Scholar) using keywords such as "Artificial Intelligence in finance," "Machine Learning financial services," "AI for risk management," "algorithmic trading AI," "Fintech AI," and "RegTech AI." The search prioritized peer-reviewed articles, conference proceedings, and relevant industry reports published within the last five years to ensure currency. Inclusion and exclusion criteria focused on studies detailing AI's practical applications, technological underpinnings, benefits, and challenges in the financial domain. The selected literature was then subjected to thematic analysis and synthesis.
#
# ### AI Applications in Finance
#
# The literature reveals a wide spectrum of AI applications revolutionizing the financial sector:
#
# *   **Algorithmic Trading and Investment Strategies:** AI is employed for high-frequency trading, predictive market modeling, and sophisticated portfolio optimization, aiming to enhance returns and manage risk.
# *   **Risk Management and Compliance:** Machine learning models are crucial for credit risk assessment, real-time fraud detection, and streamlining regulatory compliance through RegTech solutions.
# *   **Customer Service and Personalization:** AI-powered chatbots and virtual assistants are enhancing customer support, while robo-advisors offer personalized financial advice and product recommendations.
# *   **Operational Efficiency:** AI automates back-office processes, accelerates document processing, and strengthens cybersecurity measures.
#
# ### Challenges, Opportunities, and Future Directions
#
# Despite its benefits, AI integration in finance faces significant challenges. These include ensuring data quality and privacy, addressing the "black box" nature of AI models through explainability, navigating ethical concerns like algorithmic bias and job displacement, and adapting to evolving regulatory frameworks.
#
# Emerging trends point towards the growing importance of Explainable AI (XAI) for transparency, the increasing use of Generative AI in content creation and customer interaction, and the application of AI in sustainable finance (ESG investing). The intersection of AI with Decentralized Finance (DeFi) also presents a promising avenue for future research. This review highlights areas ripe for further investigation, aiming to inform future research agendas and guide responsible AI implementation.
#
# ---

# %%
## Parallel Workflows

# %%
# Tech Researcher: Focuses on AI and ML trends.
tech_researcher = Agent(
    name="TechResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research the latest AI/ML trends in psychology. Include 3 key developments,
the main companies involved, and the potential impact. Keep the report very concise (100 words).""",
    tools=[google_search],
    output_key="tech_research",  # The result of this agent will be stored in the session state with this key.
)

print("✅ tech_researcher created.")
# Out:
# ✅ tech_researcher created.

# %%
# Health Researcher: Focuses on medical breakthroughs.
health_researcher = Agent(
    name="HealthResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research recent medical breakthroughs. Include 3 significant advances,
their practical applications, and estimated timelines. Keep the report concise (100 words).""",
    tools=[google_search],
    output_key="health_research",  # The result will be stored with this key.
)

print("✅ health_researcher created.")
# Out:
# ✅ health_researcher created.

# %%
# Finance Researcher: Focuses on fintech trends.
finance_researcher = Agent(
    name="FinanceResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research current trends in economy. Include 3 key trends,
their market implications, and the future outlook. Keep the report concise (100 words).""",
    tools=[google_search],
    output_key="finance_research",  # The result will be stored with this key.
)

print("✅ finance_researcher created.")
# Out:
# ✅ finance_researcher created.

# %%
# The AggregatorAgent runs *after* the parallel step to synthesize the results.
aggregator_agent = Agent(
    name="AggregatorAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # It uses placeholders to inject the outputs from the parallel agents, which are now in the session state.
    instruction="""Combine these three research findings into a single executive summary:

    **Technology Trends:**
    {tech_research}
    
    **Health Breakthroughs:**
    {health_research}
    
    **Finance Innovations:**
    {finance_research}
    
    Your summary should highlight common themes, surprising connections, and the most important key takeaways from all three reports. The final summary should be around 200 words.""",
    output_key="executive_summary",  # This will be the final output of the entire system.
)

print("✅ aggregator_agent created.")
# Out:
# ✅ aggregator_agent created.

# %%
# The AggregatorAgent runs *after* the parallel step to synthesize the results.
aggregator_agent = Agent(
    name="AggregatorAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # It uses placeholders to inject the outputs from the parallel agents, which are now in the session state.
    instruction="""Combine these three research findings into a single executive summary:

    **Technology Trends:**
    {tech_research}
    
    **Health Breakthroughs:**
    {health_research}
    
    **Finance Innovations:**
    {finance_research}
    
    Your summary should highlight common themes, surprising connections, and the most important key takeaways from all three reports. The final summary should be around 200 words.""",
    output_key="executive_summary",  # This will be the final output of the entire system.
)

print("✅ aggregator_agent created.")
# Out:
# ✅ aggregator_agent created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Run the daily research briefing on Tech, Health, and Finance"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Run the daily research briefing on Tech, Health, and Finance
# InitialWriterAgent > The crimson sunrise bled across the smog-choked sky, a familiar sight for Anya. Her implant buzzed, a silent notification of the daily briefing. Tech: Neural interfaces saw a 12% surge in adoption, promising seamless data transfer. Health: Gene-editing breakthroughs in regenerative medicine offered hope for chronic conditions, but ethical debates raged. Finance: The global digital currency market stabilized, with a cautious optimism following last week's crash. Anya sighed, the weight of the world’s progress pressing down. She logged off, the sterile hum of her apartment a stark contrast to the vast, complex world she’d just glimpsed. Another day, another deluge of information.
# CriticAgent > Here are a few suggestions to strengthen your story:
#
# 1.  **Show, Don't Just Tell Anya's Reaction:** Instead of stating Anya sighed and felt the "weight of the world's progress," try to *show* this feeling through her actions or internal monologue. For example, she might rub her temples, her shoulders slump, or she might think about a specific, overwhelming consequence of one of the news items. This will make her emotional response more tangible for the reader.
#
# 2.  **Introduce a Specific Conflict or Goal:** The story currently presents a snapshot of Anya's morning and her general weariness. To create a stronger plot, consider what Anya *does* with this information. Does she have a job related to these fields? Is she personally affected by any of them? Giving her a specific immediate goal or a looming conflict tied to this data will drive the narrative forward.
#
# 3.  **Flesh Out the World-Building:** While the brief mentions of "smog-choked sky" and "implant" hint at a futuristic setting, there's room for more concrete details. What does this smog *do*? What are the implications of widespread neural interfaces beyond "seamless data transfer"? Adding a few more sensory details or specific societal consequences of these advancements will make the world feel more lived-in and engaging.
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File ~/code/.venv/lib/python3.12/site-packages/google/adk/models/google_llm.py:241, in Gemini.generate_content_async(self, llm_request, stream)
#     240 else:
# --> 241   response = await self.api_client.aio.models.generate_content(
#     242       model=llm_request.model,
#     243       contents=llm_request.contents,
#     244       config=llm_request.config,
#     245   )
#     246   logger.info('Response received from the model.')
#
# File ~/code/.venv/lib/python3.12/site-packages/google/genai/models.py:7033, in AsyncModels.generate_content(self, model, contents, config)
#    7026     logger.warning(
#    7027         'Tools at indices [%s] are not compatible with automatic function '
#    7028         'calling (AFC). AFC is disabled. If AFC is intended, please '
#    (...)   7031         indices_str,
#    7032     )
# -> 7033   return await self._generate_content(
#    7034       model=model, contents=contents, config=parsed_config
#    7035   )
#    7036 remaining_remote_calls_afc = _extra_utils.get_max_remote_calls_afc(
#    7037     parsed_config
#    7038 )
#
# File ~/code/.venv/lib/python3.12/site-packages/google/genai/models.py:5851, in AsyncModels._generate_content(self, model, contents, config)
#    5849 request_dict = _common.encode_unserializable_types(request_dict)
# -> 5851 response = await self._api_client.async_request(
#    5852     'post', path, request_dict, http_options
#    5853 )
#    5855 if config is not None and getattr(
#    5856     config, 'should_return_http_response', None
#    5857 ):
#
# File ~/code/.venv/lib/python3.12/site-packages/google/genai/_api_client.py:1434, in BaseApiClient.async_request(self, http_method, path, request_dict, http_options)
#    1430 http_request = self._build_request(
#    1431     http_method, path, request_dict, http_options
#    1432 )
# -> 1434 result = await self._async_request(
#    1435     http_request=http_request, http_options=http_options, stream=False
#    1436 )
#    1437 response_body = result.response_stream[0] if result.response_stream else ''
#
# File ~/code/.venv/lib/python3.12/site-packages/google/genai/_api_client.py:1367, in BaseApiClient._async_request(self, http_request, http_options, stream)
#    1366     return await retry(self._async_request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1367 return await self._async_retry(  # type: ignore[no-any-return]
#    1368     self._async_request_once, http_request, stream
#    1369 )
#
# File ~/code/.venv/lib/python3.12/site-packages/tenacity/asyncio/__init__.py:111, in AsyncRetrying.__call__(self, fn, *args, **kwargs)
#     110 while True:
# --> 111     do = await self.iter(retry_state=retry_state)
#     112     if isinstance(do, DoAttempt):
#
# File ~/code/.venv/lib/python3.12/site-packages/tenacity/asyncio/__init__.py:153, in AsyncRetrying.iter(self, retry_state)
#     152 for action in self.iter_state.actions:
# --> 153     result = await action(retry_state)
#     154 return result
#
# File ~/code/.venv/lib/python3.12/site-packages/tenacity/_utils.py:99, in wrap_to_async_func.<locals>.inner(*args, **kwargs)
#      98 async def inner(*args: typing.Any, **kwargs: typing.Any) -> typing.Any:
# ---> 99     return call(*args, **kwargs)
#
# File ~/code/.venv/lib/python3.12/site-packages/tenacity/__init__.py:420, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     419 if self.reraise:
# --> 420     raise retry_exc.reraise()
#     421 raise retry_exc from fut.exception()
#
# File ~/code/.venv/lib/python3.12/site-packages/tenacity/__init__.py:187, in RetryError.reraise(self)
#     186 if self.last_attempt.failed:
# --> 187     raise self.last_attempt.result()
#     188 raise self
#
# File /opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#
# File /opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     400 try:
# --> 401     raise self._exception
#     402 finally:
#     403     # Break a reference cycle with the exception in self._exception
#
# File ~/code/.venv/lib/python3.12/site-packages/tenacity/asyncio/__init__.py:114, in AsyncRetrying.__call__(self, fn, *args, **kwargs)
#     113 try:
# --> 114     result = await fn(*args, **kwargs)
#     115 except BaseException:  # noqa: B902
#
# File ~/code/.venv/lib/python3.12/site-packages/google/genai/_api_client.py:1312, in BaseApiClient._async_request_once(self, http_request, stream)
#    1304 response = await self._aiohttp_session.request(
#    1305     method=http_request.method,
#    1306     url=http_request.url,
#    (...)   1310     **self._async_client_session_request_args,
#    1311 )
# -> 1312 await errors.APIError.raise_for_async_response(response)
#    1313 return HttpResponse(response.headers, [await response.text()])
#
# File ~/code/.venv/lib/python3.12/site-packages/google/genai/errors.py:203, in APIError.raise_for_async_response(cls, response)
#     201     raise ValueError(f'Unsupported response type: {type(response)}')
# --> 203 await cls.raise_error_async(status_code, response_json, response)
#
# File ~/code/.venv/lib/python3.12/site-packages/google/genai/errors.py:225, in APIError.raise_error_async(cls, status_code, response_json, response)
#     224 if 400 <= status_code < 500:
# --> 225   raise ClientError(status_code, response_json, response)
#     226 elif 500 <= status_code < 600:
#
# ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash-lite\nPlease retry in 6.067216737s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '6s'}]}}
#
# The above exception was the direct cause of the following exception:
#
# _ResourceExhaustedError                   Traceback (most recent call last)
# Cell In[17], line 2
#       1 runner = InMemoryRunner(agent=root_agent)
# ----> 2 response = await runner.run_debug(
#       3     "Run the daily research briefing on Tech, Health, and Finance"
#       4 )
#
# File ~/code/.venv/lib/python3.12/site-packages/google/adk/runners.py:1168, in Runner.run_debug(self, user_messages, user_id, session_id, run_config, quiet, verbose)
#    1165 if not quiet:
#    1166   print(f'\nUser > {message}')
# -> 1168 async for event in self.run_async(
#    1169     user_id=user_id,
#    1170     session_id=session.id,
#    1171     new_message=types.UserContent(parts=[types.Part(text=message)]),
#    1172     run_config=run_config,
#    1173 ):
#    1174   if not quiet:
#    1175     print_event(event, verbose=verbose)
#
# File ~/code/.venv/lib/python3.12/site-packages/google/adk/runners.py:505, in Runner.run_async(self, user_id, session_id, invocation_id, new_message, state_delta, run_config)
#     500       await _run_compaction_for_sliding_window(
#     501           self.app, session, self.session_service
#     502       )
#     504 async with Aclosing(_run_with_trace(new_message, invocation_id)) as agen:
# --> 505   async for event in agen:
#     506     yield event
#
# File ~/code/.venv/lib/python3.12/site-packages/google/adk/runners.py:493, in Runner.run_async.<locals>._run_with_trace(new_message, invocation_id)
#     483       yield event
#     485 async with Aclosing(
#     486     self._exec_with_plugin(
#     487         invocation_context=invocation_context,
#    (...)    491     )
#     492 ) as agen:
# --> 493   async for event in agen:
#     494     yield event
#     495 # Run compaction after all events are yielded from the agent.
#     496 # (We don't compact in the middle of an invocation, we only compact at
#     497 # the end of an invocation.)
#
# File ~/code/.venv/lib/python3.12/site-packages/google/adk/runners.py:722, in Runner._exec_with_plugin(self, invocation_context, session, execute_fn, is_live_call)
#     719 is_transcribing: bool = False
#     721 async with Aclosing(execute_fn(invocation_context)) as agen:
# --> 722   async for event in agen:
#     723     if is_live_call:
#     724       if event.partial and _is_transcription(event):
#
# File ~/code/.venv/lib/python3.12/site-packages/google/adk/runners.py:482, in Runner.run_async.<locals>._run_with_trace.<locals>.execute(ctx)
#     480 async def execute(ctx: InvocationContext) -> AsyncGenerator[Event]:
#     481   async with Aclosing(ctx.agent.run_async(ctx)) as agen:
# --> 482     async for event in agen:
#     483       yield event
#
# File ~/code/.venv/lib/python3.12/site-packages/google/adk/agents/base_agent.py:294, in BaseAgent.run_async(self, parent_context)
#     291   return
#     293 async with Aclosing(self._run_async_impl(ctx)) as agen:
# --> 294   async for event in agen:
#     295     yield event
#     297 if ctx.end_invocation:
#
# File ~/code/.venv/lib/python3.12/site-packages/google/adk/agents/sequential_agent.py:77, in SequentialAgent._run_async_impl(self, ctx)
#      74     yield self._create_agent_state_event(ctx)
#      76 async with Aclosing(sub_agent.run_async(ctx)) as agen:
# ---> 77   async for event in agen:
#      78     yield event
#      79     if ctx.should_pause_invocation(event):
#
# File ~/code/.venv/lib/python3.12/site-packages/google/adk/agents/base_agent.py:294, in BaseAgent.run_async(self, parent_context)
#     291   return
#     293 async with Aclosing(self._run_async_impl(ctx)) as agen:
# --> 294   async for event in agen:
#     295     yield event
#     297 if ctx.end_invocation:
#
# File ~/code/.venv/lib/python3.12/site-packages/google/adk/agents/loop_agent.py:100, in LoopAgent._run_async_impl(self, ctx)
#      97 is_resuming_at_current_agent = False
#      99 async with Aclosing(sub_agent.run_async(ctx)) as agen:
# --> 100   async for event in agen:
#     101     yield event
#     102     if event.actions.escalate:
#
# File ~/code/.venv/lib/python3.12/site-packages/google/adk/agents/base_agent.py:294, in BaseAgent.run_async(self, parent_context)
#     291   return
#     293 async with Aclosing(self._run_async_impl(ctx)) as agen:
# --> 294   async for event in agen:
#     295     yield event
#     297 if ctx.end_invocation:
#
# File ~/code/.venv/lib/python3.12/site-packages/google/adk/agents/llm_agent.py:460, in LlmAgent._run_async_impl(self, ctx)
#     458 should_pause = False
#     459 async with Aclosing(self._llm_flow.run_async(ctx)) as agen:
# --> 460   async for event in agen:
#     461     self.__maybe_save_output_to_state(event)
#     462     yield event
#
# File ~/code/.venv/lib/python3.12/site-packages/google/adk/flows/llm_flows/base_llm_flow.py:370, in BaseLlmFlow.run_async(self, invocation_context)
#     368 last_event = None
#     369 async with Aclosing(self._run_one_step_async(invocation_context)) as agen:
# --> 370   async for event in agen:
#     371     last_event = event
#     372     yield event
#
# File ~/code/.venv/lib/python3.12/site-packages/google/adk/flows/llm_flows/base_llm_flow.py:447, in BaseLlmFlow._run_one_step_async(self, invocation_context)
#     436 model_response_event = Event(
#     437     id=Event.new_id(),
#     438     invocation_id=invocation_context.invocation_id,
#     439     author=invocation_context.agent.name,
#     440     branch=invocation_context.branch,
#     441 )
#     442 async with Aclosing(
#     443     self._call_llm_async(
#     444         invocation_context, llm_request, model_response_event
#     445     )
#     446 ) as agen:
# --> 447   async for llm_response in agen:
#     448     # Postprocess after calling the LLM.
#     449     async with Aclosing(
#     450         self._postprocess_async(
#     451             invocation_context,
#    (...)    455         )
#     456     ) as agen:
#     457       async for event in agen:
#     458         # Update the mutable event id to avoid conflict
#
# File ~/code/.venv/lib/python3.12/site-packages/google/adk/flows/llm_flows/base_llm_flow.py:816, in BaseLlmFlow._call_llm_async(self, invocation_context, llm_request, model_response_event)
#     813           yield llm_response
#     815 async with Aclosing(_call_llm_with_tracing()) as agen:
# --> 816   async for event in agen:
#     817     yield event
#
# File ~/code/.venv/lib/python3.12/site-packages/google/adk/flows/llm_flows/base_llm_flow.py:800, in BaseLlmFlow._call_llm_async.<locals>._call_llm_with_tracing()
#     787 responses_generator = llm.generate_content_async(
#     788     llm_request,
#     789     stream=invocation_context.run_config.streaming_mode
#     790     == StreamingMode.SSE,
#     791 )
#     792 async with Aclosing(
#     793     self._run_and_handle_error(
#     794         responses_generator,
#    (...)    798     )
#     799 ) as agen:
# --> 800   async for llm_response in agen:
#     801     trace_call_llm(
#     802         invocation_context,
#     803         model_response_event.id,
#     804         llm_request,
#     805         llm_response,
#     806     )
#     807     # Runs after_model_callback if it exists.
#
# File ~/code/.venv/lib/python3.12/site-packages/google/adk/flows/llm_flows/base_llm_flow.py:1053, in BaseLlmFlow._run_and_handle_error(self, response_generator, invocation_context, llm_request, model_response_event)
#    1051   yield error_response
#    1052 else:
# -> 1053   raise model_error
#
# File ~/code/.venv/lib/python3.12/site-packages/google/adk/flows/llm_flows/base_llm_flow.py:1039, in BaseLlmFlow._run_and_handle_error(self, response_generator, invocation_context, llm_request, model_response_event)
#    1037 try:
#    1038   async with Aclosing(response_generator) as agen:
# -> 1039     async for response in agen:
#    1040       yield response
#    1041 except Exception as model_error:
#
# File ~/code/.venv/lib/python3.12/site-packages/google/adk/models/google_llm.py:260, in Gemini.generate_content_async(self, llm_request, stream)
#     255 except ClientError as ce:
#     256   if ce.code == 429:
#     257     # We expect running into a Resource Exhausted error to be a common
#     258     # client error that developers would run into. We enhance the messaging
#     259     # with possible fixes to this issue.
# --> 260     raise _ResourceExhaustedError(ce) from ce
#     262   raise ce
#
# _ResourceExhaustedError:
# On how to mitigate this issue, please refer to:
#
# https://google.github.io/adk-docs/agents/models/#error-code-429-resource_exhausted
#
#
# 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash-lite\nPlease retry in 6.067216737s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '6s'}]}}

# %% [markdown]
# ## Loop Workflows - The Refinement Cycle

# %%
# This agent runs ONCE at the beginning to create the first draft.
initial_writer_agent = Agent(
    name="InitialWriterAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Based on the user's prompt, write the first draft of a research proposal (around 100-150 words).
    Output only the text of the draft, with no introduction or explanation.""",
    output_key="current_draft",  # Stores the first draft in the state.
)

print("✅ initial_writer_agent created.")

# This agent's only job is to provide feedback or the approval signal. It has no tools.
critic_agent = Agent(
    name="CriticAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a constructive story critic. Review the story provided below.
    Story: {current_story}
    
    Evaluate the story's plot, characters, and pacing.
    - If the story is well-written and complete, you MUST respond with the exact phrase: "APPROVED"
    - Otherwise, provide 2-3 specific, actionable suggestions for improvement.""",
    output_key="critique",  # Stores the feedback in the state.
)

print("✅ critic_agent created.")

# This is the function that the RefinerAgent will call to exit the loop.
def exit_loop():
    """Call this function ONLY when the critique is 'APPROVED', indicating the story is finished and no more changes are needed."""
    return {"status": "approved", "message": "Story approved. Exiting refinement loop."}


print("✅ exit_loop function created.")


# This agent refines the story based on critique OR calls the exit_loop function.
refiner_agent = Agent(
    name="RefinerAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a story refiner. You have a story draft and critique.
    
    Story Draft: {current_story}
    Critique: {critique}
    
    Your task is to analyze the critique.
    - IF the critique is EXACTLY "APPROVED", you MUST call the `exit_loop` function and nothing else.
    - OTHERWISE, rewrite the story draft to fully incorporate the feedback from the critique.""",
    output_key="current_story",  # It overwrites the story with the new, refined version.
    tools=[
        FunctionTool(exit_loop)
    ],  # The tool is now correctly initialized with the function reference.
)

print("✅ refiner_agent created.")


# The LoopAgent contains the agents that will run repeatedly: Critic -> Refiner.
story_refinement_loop = LoopAgent(
    name="StoryRefinementLoop",
    sub_agents=[critic_agent, refiner_agent],
    max_iterations=2,  # Prevents infinite loops
)

# The root agent is a SequentialAgent that defines the overall workflow: Initial Write -> Refinement Loop.
root_agent = SequentialAgent(
    name="StoryPipeline",
    sub_agents=[initial_writer_agent, story_refinement_loop],
)

print("✅ Loop and Sequential Agents created.")
# Out:
# ✅ initial_writer_agent created.
# ✅ critic_agent created.
# ✅ exit_loop function created.
# ✅ refiner_agent created.
# ✅ Loop and Sequential Agents created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Write a short story about a lighthouse keeper who discovers a mysterious, glowing map"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Write a short story about a lighthouse keeper who discovers a mysterious, glowing map
# InitialWriterAgent > The salt spray kissed Silas’s weathered face as he climbed the winding stairs, the oil lamp casting dancing shadows. For fifty years, the lighthouse had been his world, its beam his only constant companion. Tonight, however, a faint, ethereal glow emanated from his battered sea chest. Puzzled, he lifted the heavy lid.
#
# Nestled amongst old charts and barnacle-encrusted tools lay a vellum map, unlike any he’d ever seen. Strange, swirling symbols pulsed with a soft, cerulean light, illuminating intricate coastlines and unknown islands. A single, glowing 'X' marked a spot far out in the uncharted abyss. Silas, his heart pounding with a thrill he hadn't felt since his youth, traced the luminous lines with a trembling finger. The sea, his lifelong mistress, had just whispered a new secret.
# CriticAgent > The story is a good start, creating immediate intrigue with the glowing map. Here are a few suggestions for improvement:
#
# 1.  **Expand on Silas's character and motivations:** While we learn he's been a lighthouse keeper for fifty years and feels a youthful thrill, delve a little deeper. What are his regrets or unfulfilled desires? What makes this map specifically compelling to *him* after such a long, solitary life? Showing a brief flashback or an internal monologue about what this discovery might mean for him personally would add depth.
#
# 2.  **Develop the mystery of the map:** The map is described as having strange, swirling symbols and unknown islands. To heighten the mystery and encourage further storytelling, consider hinting at the origin or purpose of the map. Is it ancient? Magical? Alien? A brief, subtle clue – perhaps a faint, unfamiliar scent from the vellum, or a symbol that seems to shift when Silas isn't looking directly at it – could spark the reader's imagination.
#
# 3.  **Introduce a hint of immediate consequence or a decision point:** The story ends with Silas tracing the lines. What is his immediate reaction or next step? Does he feel fear, excitement, or a sense of destiny? Having him make a small, immediate decision or express a clear, pressing question would provide a stronger hook for what might happen next, rather than leaving him in a moment of contemplation.
# RefinerAgent > The salt spray kissed Silas’s weathered face as he climbed the winding stairs, the oil lamp casting dancing shadows. For fifty years, the lighthouse had been his world, its beam his only constant companion. He’d long ago made peace with the quiet, the solitude, though sometimes, in the deep watches of the night, a pang of regret would surface – for the wife he never found, the adventures he never took. Tonight, however, a faint, ethereal glow emanated from his battered sea chest, pulling him from his reverie. Puzzled, he lifted the heavy lid.
#
# Nestled amongst old charts and barnacle-encrusted tools lay a vellum map, unlike any he’d ever seen. Strange, swirling symbols pulsed with a soft, cerulean light, illuminating intricate coastlines and unknown islands. A faint, ozone-like scent, alien to the familiar brine and tar of his life, rose from the ancient vellum. As Silas watched, one of the symbols, a coiling serpent, seemed to writhe, its eye glinting malevolently. A single, glowing 'X' marked a spot far out in the uncharted abyss. Silas, his heart pounding with a thrill he hadn't felt since his youth, traced the luminous lines with a trembling finger. This wasn't just a map; it was a siren's call, a promise of the unknown that the sea, his lifelong mistress, had finally deemed him ready to hear. A single question burned in his mind: could he, a man of routine and predictable tides, dare to answer? He closed the chest, the glowing 'X' imprinted on his vision, a stark contrast to the steady, familiar beam sweeping across the dark ocean.
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File ~/code/.venv/lib/python3.12/site-packages/google/adk/models/google_llm.py:241, in Gemini.generate_content_async(self, llm_request, stream)
#     240 else:
# --> 241   response = await self.api_client.aio.models.generate_content(
#     242       model=llm_request.model,
#     243       contents=llm_request.contents,
#     244       config=llm_request.config,
#     245   )
#     246   logger.info('Response received from the model.')
#
# File ~/code/.venv/lib/python3.12/site-packages/google/genai/models.py:7045, in AsyncModels.generate_content(self, model, contents, config)
#    7044 while remaining_remote_calls_afc > 0:
# -> 7045   response = await self._generate_content(
#    7046       model=model, contents=contents, config=parsed_config
#    7047   )
#    7048   remaining_remote_calls_afc -= 1
#
# File ~/code/.venv/lib/python3.12/site-packages/google/genai/models.py:5851, in AsyncModels._generate_content(self, model, contents, config)
#    5849 request_dict = _common.encode_unserializable_types(request_dict)
# -> 5851 response = await self._api_client.async_request(
#    5852     'post', path, request_dict, http_options
#    5853 )
#    5855 if config is not None and getattr(
#    5856     config, 'should_return_http_response', None
#    5857 ):
#
# File ~/code/.venv/lib/python3.12/site-packages/google/genai/_api_client.py:1434, in BaseApiClient.async_request(self, http_method, path, request_dict, http_options)
#    1430 http_request = self._build_request(
#    1431     http_method, path, request_dict, http_options
#    1432 )
# -> 1434 result = await self._async_request(
#    1435     http_request=http_request, http_options=http_options, stream=False
#    1436 )
#    1437 response_body = result.response_stream[0] if result.response_stream else ''
#
# File ~/code/.venv/lib/python3.12/site-packages/google/genai/_api_client.py:1367, in BaseApiClient._async_request(self, http_request, http_options, stream)
#    1366     return await retry(self._async_request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1367 return await self._async_retry(  # type: ignore[no-any-return]
#    1368     self._async_request_once, http_request, stream
#    1369 )
#
# File ~/code/.venv/lib/python3.12/site-packages/tenacity/asyncio/__init__.py:111, in AsyncRetrying.__call__(self, fn, *args, **kwargs)
#     110 while True:
# --> 111     do = await self.iter(retry_state=retry_state)
#     112     if isinstance(do, DoAttempt):
#
# File ~/code/.venv/lib/python3.12/site-packages/tenacity/asyncio/__init__.py:153, in AsyncRetrying.iter(self, retry_state)
#     152 for action in self.iter_state.actions:
# --> 153     result = await action(retry_state)
#     154 return result
#
# File ~/code/.venv/lib/python3.12/site-packages/tenacity/_utils.py:99, in wrap_to_async_func.<locals>.inner(*args, **kwargs)
#      98 async def inner(*args: typing.Any, **kwargs: typing.Any) -> typing.Any:
# ---> 99     return call(*args, **kwargs)
#
# File ~/code/.venv/lib/python3.12/site-packages/tenacity/__init__.py:420, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     419 if self.reraise:
# --> 420     raise retry_exc.reraise()
#     421 raise retry_exc from fut.exception()
#
# File ~/code/.venv/lib/python3.12/site-packages/tenacity/__init__.py:187, in RetryError.reraise(self)
#     186 if self.last_attempt.failed:
# --> 187     raise self.last_attempt.result()
#     188 raise self
#
# File /opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#
# File /opt/homebrew/Cellar/python@3.12/3.12.11/Frameworks/Python.framework/Versions/3.12/lib/python3.12/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     400 try:
# --> 401     raise self._exception
#     402 finally:
#     403     # Break a reference cycle with the exception in self._exception
#
# File ~/code/.venv/lib/python3.12/site-packages/tenacity/asyncio/__init__.py:114, in AsyncRetrying.__call__(self, fn, *args, **kwargs)
#     113 try:
# --> 114     result = await fn(*args, **kwargs)
#     115 except BaseException:  # noqa: B902
#
# File ~/code/.venv/lib/python3.12/site-packages/google/genai/_api_client.py:1312, in BaseApiClient._async_request_once(self, http_request, stream)
#    1304 response = await self._aiohttp_session.request(
#    1305     method=http_request.method,
#    1306     url=http_request.url,
#    (...)   1310     **self._async_client_session_request_args,
#    1311 )
# -> 1312 await errors.APIError.raise_for_async_response(response)
#    1313 return HttpResponse(response.headers, [await response.text()])
#
# File ~/code/.venv/lib/python3.12/site-packages/google/genai/errors.py:203, in APIError.raise_for_async_response(cls, response)
#     201     raise ValueError(f'Unsupported response type: {type(response)}')
# --> 203 await cls.raise_error_async(status_code, response_json, response)
#
# File ~/code/.venv/lib/python3.12/site-packages/google/genai/errors.py:225, in APIError.raise_error_async(cls, status_code, response_json, response)
#     224 if 400 <= status_code < 500:
# --> 225   raise ClientError(status_code, response_json, response)
#     226 elif 500 <= status_code < 600:
#
# ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash-lite\nPlease retry in 33.473432541s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash-lite', 'location': 'global'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '33s'}]}}
#
# The above exception was the direct cause of the following exception:
#
# _ResourceExhaustedError                   Traceback (most recent call last)
# Cell In[16], line 2
#       1 runner = InMemoryRunner(agent=root_agent)
# ----> 2 response = await runner.run_debug(
#       3     "Write a short story about a lighthouse keeper who discovers a mysterious, glowing map"
#       4 )
#
# File ~/code/.venv/lib/python3.12/site-packages/google/adk/runners.py:1168, in Runner.run_debug(self, user_messages, user_id, session_id, run_config, quiet, verbose)
#    1165 if not quiet:
#    1166   print(f'\nUser > {message}')
# -> 1168 async for event in self.run_async(
#    1169     user_id=user_id,
#    1170     session_id=session.id,
#    1171     new_message=types.UserContent(parts=[types.Part(text=message)]),
#    1172     run_config=run_config,
#    1173 ):
#    1174   if not quiet:
#    1175     print_event(event, verbose=verbose)
#
# File ~/code/.venv/lib/python3.12/site-packages/google/adk/runners.py:505, in Runner.run_async(self, user_id, session_id, invocation_id, new_message, state_delta, run_config)
#     500       await _run_compaction_for_sliding_window(
#     501           self.app, session, self.session_service
#     502       )
#     504 async with Aclosing(_run_with_trace(new_message, invocation_id)) as agen:
# --> 505   async for event in agen:
#     506     yield event
#
# File ~/code/.venv/lib/python3.12/site-packages/google/adk/runners.py:493, in Runner.run_async.<locals>._run_with_trace(new_message, invocation_id)
#     483       yield event
#     485 async with Aclosing(
#     486     self._exec_with_plugin(
#     487         invocation_context=invocation_context,
#    (...)    491     )
#     492 ) as agen:
# --> 493   async for event in agen:
#     494     yield event
#     495 # Run compaction after all events are yielded from the agent.
#     496 # (We don't compact in the middle of an invocation, we only compact at
#     497 # the end of an invocation.)
#
# File ~/code/.venv/lib/python3.12/site-packages/google/adk/runners.py:722, in Runner._exec_with_plugin(self, invocation_context, session, execute_fn, is_live_call)
#     719 is_transcribing: bool = False
#     721 async with Aclosing(execute_fn(invocation_context)) as agen:
# --> 722   async for event in agen:
#     723     if is_live_call:
#     724       if event.partial and _is_transcription(event):
#
# File ~/code/.venv/lib/python3.12/site-packages/google/adk/runners.py:482, in Runner.run_async.<locals>._run_with_trace.<locals>.execute(ctx)
#     480 async def execute(ctx: InvocationContext) -> AsyncGenerator[Event]:
#     481   async with Aclosing(ctx.agent.run_async(ctx)) as agen:
# --> 482     async for event in agen:
#     483       yield event
#
# File ~/code/.venv/lib/python3.12/site-packages/google/adk/agents/base_agent.py:294, in BaseAgent.run_async(self, parent_context)
#     291   return
#     293 async with Aclosing(self._run_async_impl(ctx)) as agen:
# --> 294   async for event in agen:
#     295     yield event
#     297 if ctx.end_invocation:
#
# File ~/code/.venv/lib/python3.12/site-packages/google/adk/agents/sequential_agent.py:77, in SequentialAgent._run_async_impl(self, ctx)
#      74     yield self._create_agent_state_event(ctx)
#      76 async with Aclosing(sub_agent.run_async(ctx)) as agen:
# ---> 77   async for event in agen:
#      78     yield event
#      79     if ctx.should_pause_invocation(event):
#
# File ~/code/.venv/lib/python3.12/site-packages/google/adk/agents/base_agent.py:294, in BaseAgent.run_async(self, parent_context)
#     291   return
#     293 async with Aclosing(self._run_async_impl(ctx)) as agen:
# --> 294   async for event in agen:
#     295     yield event
#     297 if ctx.end_invocation:
#
# File ~/code/.venv/lib/python3.12/site-packages/google/adk/agents/loop_agent.py:100, in LoopAgent._run_async_impl(self, ctx)
#      97 is_resuming_at_current_agent = False
#      99 async with Aclosing(sub_agent.run_async(ctx)) as agen:
# --> 100   async for event in agen:
#     101     yield event
#     102     if event.actions.escalate:
#
# File ~/code/.venv/lib/python3.12/site-packages/google/adk/agents/base_agent.py:294, in BaseAgent.run_async(self, parent_context)
#     291   return
#     293 async with Aclosing(self._run_async_impl(ctx)) as agen:
# --> 294   async for event in agen:
#     295     yield event
#     297 if ctx.end_invocation:
#
# File ~/code/.venv/lib/python3.12/site-packages/google/adk/agents/llm_agent.py:460, in LlmAgent._run_async_impl(self, ctx)
#     458 should_pause = False
#     459 async with Aclosing(self._llm_flow.run_async(ctx)) as agen:
# --> 460   async for event in agen:
#     461     self.__maybe_save_output_to_state(event)
#     462     yield event
#
# File ~/code/.venv/lib/python3.12/site-packages/google/adk/flows/llm_flows/base_llm_flow.py:370, in BaseLlmFlow.run_async(self, invocation_context)
#     368 last_event = None
#     369 async with Aclosing(self._run_one_step_async(invocation_context)) as agen:
# --> 370   async for event in agen:
#     371     last_event = event
#     372     yield event
#
# File ~/code/.venv/lib/python3.12/site-packages/google/adk/flows/llm_flows/base_llm_flow.py:447, in BaseLlmFlow._run_one_step_async(self, invocation_context)
#     436 model_response_event = Event(
#     437     id=Event.new_id(),
#     438     invocation_id=invocation_context.invocation_id,
#     439     author=invocation_context.agent.name,
#     440     branch=invocation_context.branch,
#     441 )
#     442 async with Aclosing(
#     443     self._call_llm_async(
#     444         invocation_context, llm_request, model_response_event
#     445     )
#     446 ) as agen:
# --> 447   async for llm_response in agen:
#     448     # Postprocess after calling the LLM.
#     449     async with Aclosing(
#     450         self._postprocess_async(
#     451             invocation_context,
#    (...)    455         )
#     456     ) as agen:
#     457       async for event in agen:
#     458         # Update the mutable event id to avoid conflict
#
# File ~/code/.venv/lib/python3.12/site-packages/google/adk/flows/llm_flows/base_llm_flow.py:816, in BaseLlmFlow._call_llm_async(self, invocation_context, llm_request, model_response_event)
#     813           yield llm_response
#     815 async with Aclosing(_call_llm_with_tracing()) as agen:
# --> 816   async for event in agen:
#     817     yield event
#
# File ~/code/.venv/lib/python3.12/site-packages/google/adk/flows/llm_flows/base_llm_flow.py:800, in BaseLlmFlow._call_llm_async.<locals>._call_llm_with_tracing()
#     787 responses_generator = llm.generate_content_async(
#     788     llm_request,
#     789     stream=invocation_context.run_config.streaming_mode
#     790     == StreamingMode.SSE,
#     791 )
#     792 async with Aclosing(
#     793     self._run_and_handle_error(
#     794         responses_generator,
#    (...)    798     )
#     799 ) as agen:
# --> 800   async for llm_response in agen:
#     801     trace_call_llm(
#     802         invocation_context,
#     803         model_response_event.id,
#     804         llm_request,
#     805         llm_response,
#     806     )
#     807     # Runs after_model_callback if it exists.
#
# File ~/code/.venv/lib/python3.12/site-packages/google/adk/flows/llm_flows/base_llm_flow.py:1053, in BaseLlmFlow._run_and_handle_error(self, response_generator, invocation_context, llm_request, model_response_event)
#    1051   yield error_response
#    1052 else:
# -> 1053   raise model_error
#
# File ~/code/.venv/lib/python3.12/site-packages/google/adk/flows/llm_flows/base_llm_flow.py:1039, in BaseLlmFlow._run_and_handle_error(self, response_generator, invocation_context, llm_request, model_response_event)
#    1037 try:
#    1038   async with Aclosing(response_generator) as agen:
# -> 1039     async for response in agen:
#    1040       yield response
#    1041 except Exception as model_error:
#
# File ~/code/.venv/lib/python3.12/site-packages/google/adk/models/google_llm.py:260, in Gemini.generate_content_async(self, llm_request, stream)
#     255 except ClientError as ce:
#     256   if ce.code == 429:
#     257     # We expect running into a Resource Exhausted error to be a common
#     258     # client error that developers would run into. We enhance the messaging
#     259     # with possible fixes to this issue.
# --> 260     raise _ResourceExhaustedError(ce) from ce
#     262   raise ce
#
# _ResourceExhaustedError:
# On how to mitigate this issue, please refer to:
#
# https://google.github.io/adk-docs/agents/models/#error-code-429-resource_exhausted
#
#
# 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash-lite\nPlease retry in 33.473432541s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash-lite', 'location': 'global'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '33s'}]}}
